# %%
import pandas as pd

# %%
pd.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pd.__version__
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 42.7 MB 85 kB/s s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
